# %% [markdown]
# # Ateliê Generativo — Treinamento LoRA (Google Colab / GPU T4)
#
# Notebook-guia da **Etapa 2**. Treina o adaptador LoRA de pixel art 16 bits.
#
# **Antes de começar:** Runtime → Alterar tipo de runtime → **GPU (T4)**.

# %% [markdown]
# **1 - Infraestrutura, Otimização e Armazenamento Persistente**

# %%
# Célula 1: Montagem do Drive e Instalação do Ecossistema
from google.colab import drive
drive.mount('/content/drive')

import os
# Cria o diretório de destino no seu Google Drive
drive_path = "/content/drive/MyDrive/Atelie_Generativo_LoRA"
os.makedirs(drive_path, exist_ok=True)
print(f"📁 Pasta de salvamento criada em: {drive_path}")

# Instalação das bibliotecas com versões otimizadas para GPU T4
# !pip install -q -U transformers accelerate peft bitsandbytes datasets xformers torchao

# Instalação da biblioteca diffusers (cutting-edge)
# !pip install -q git+https://github.com/huggingface/diffusers.git

# Clonagem do repositório oficial da Hugging Face para acesso ao script de treinamento
# !git clone https://github.com/huggingface/diffusers.git
# Out:
# Mounted at /content/drive
# 📁 Pasta de salvamento garantida em: /content/drive/MyDrive/Atelie_Generativo_LoRA
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 110.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 18.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 555.1/555.1 kB 45.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 103.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 99.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 MB 19.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for diffusers (pyproject.toml) ... done
# Cloning into 'diffusers'...
# remote: Enumerating objects: 126063, done.
# remote: Counting objects: 100% (1196/1196), done.
# remote: Compressing objects: 100% (817/817), done.
# remote: Total 126063 (delta 787), reused 431 (delta 371), pack-reused 124867 (from 5)
# Receiving objects: 100% (126063/126063), 100.53 MiB | 27.26 MiB/s, done.
# Resolving deltas: 100% (93704/93704), done.

# %% [markdown]
# **2 - Ingestão de Dados e Mapeamento de Caminhos (Atualizado)**

# %%
# Célula 2: Download do Dataset e Construção do metadata.jsonl
import json

# Clona o repositório da equipe
# !git clone https://github.com/Thiagofariasl/atelie-generativo-estilo-pixel-art.git

# Definição dos caminhos base
dataset_dir = "/content/atelie-generativo-estilo-pixel-art/dataset"
txt_file = os.path.join(dataset_dir, "legendas.txt")
jsonl_file = os.path.join(dataset_dir, "metadata.jsonl")

# Lógica de conversão adaptada para a arquitetura do GitHub
# Transforma: "img_01.jpg: legenda" -> {"file_name": "images/img_01.jpg", "text": "legenda"}
with open(txt_file, 'r', encoding='utf-8') as f_in, open(jsonl_file, 'w', encoding='utf-8') as f_out:
    for linha in f_in:
        if ':' in linha:
            arquivo, legenda = linha.split(':', 1)

            # Adicionando o prefixo da subpasta para garantir que o Diffusers encontre a imagem
            caminho_relativo = f"images/{arquivo.strip()}"

            json_obj = {"file_name": caminho_relativo, "text": legenda.strip()}
            f_out.write(json.dumps(json_obj) + '\n')

print("✅ Dataset preparado! O arquivo metadata.jsonl mapeia corretamente a subpasta 'images/'.")
# Out:
# Cloning into 'atelie-generativo-estilo-pixel-art'...
# remote: Enumerating objects: 194, done.
# remote: Counting objects: 100% (194/194), done.
# remote: Compressing objects: 100% (184/184), done.
# remote: Total 194 (delta 32), reused 142 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (194/194), 18.02 MiB | 22.00 MiB/s, done.
# Resolving deltas: 100% (32/32), done.
# ✅ Dataset preparado! O arquivo metadata.jsonl agora mapeia corretamente a subpasta 'images/'.

# %% [markdown]
# **3 - Configuração do Accelerate**

# %%
# Célula 3: Configuração do hardware
from accelerate.utils import write_basic_config
write_basic_config()
print("🚀 Accelerate configurado para maximizar a eficiência da GPU T4!")
# Out:
# 🚀 Accelerate configurado para maximizar a eficiência da GPU T4!

# %% [markdown]
# **4 - O Treinamento Matemático (As Duas Configurações Exigidas)**
#
# > Execute a Célula 4A, aguarde terminar (pode levar 20-40 min dependendo do número de épocas/imagens).
# > Quando concluir, execute a 4B.

# %%
# Célula 4A: CONFIGURAÇÃO A (Rank 8) - Generalização de Estilo
# !accelerate launch diffusers/examples/text_to_image/train_text_to_image_lora.py \
  --pretrained_model_name_or_path="runwayml/stable-diffusion-v1-5" \
  --dataset_name="/content/atelie-generativo-estilo-pixel-art/dataset" \
  --dataloader_num_workers=8 \
  --resolution=512 \
  --center_crop \
  --random_flip \
  --train_batch_size=1 \
  --gradient_accumulation_steps=4 \
  --max_train_steps=1000 \
  --learning_rate=1e-04 \
  --max_grad_norm=1 \
  --lr_scheduler="cosine" \
  --lr_warmup_steps=0 \
  --output_dir="/content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank8" \
  --checkpointing_steps=500 \
  --seed=42 \
  --rank=8 \
  --mixed_precision="fp16" \
  --enable_xformers_memory_efficient_attention
# Out:
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Unable to import `torchao` Tensor objects. This may affect loading checkpoints serialized with `torchao`
# Flax classes are deprecated and will be removed in Diffusers v0.40.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v0.40.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# 06/26/2026 23:43:32 - INFO - __main__ - [RANK 0] Distributed environment: DistributedType.NO
# Num processes: 1
# Process index: 0
# Local process index: 0
# Device: cuda
#
# Mixed precision type: fp16
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py:205: UserWarning: The `local_dir_use_symlinks` argument is deprecated and ignored in `hf_hub_download`. Downloading to a local directory does not use symlinks anymore.
#   warnings.warn(
# 06/26/2026 23:43:32 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/agent-harnesses "HTTP/1.1 200 OK"
# 06/26/2026 23:43:32 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/scheduler/scheduler_config.json "HTTP/1.1 307 Temporary Redirect"
# 06/26/2026 23:43:32 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/scheduler/scheduler_config.json "HTTP/1.1 307 Temporary Redirect"
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 06/26/2026 23:43:32 - WARNING - huggingface_hub.utils._http - Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 06/26/2026 23:43:32 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/scheduler%2Fscheduler_config.json "HTTP/1.1 200 OK"
# 06/26/2026 23:43:32 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/scheduler%2Fscheduler_config.json "HTTP/1.1 200 OK"
# scheduler_config.json: 100% 308/308 [00:00<00:00, 1.27MB/s]
# {'timestep_spacing', 'clip_sample_range', 'thresholding', 'variance_type', 'sample_max_value', 'prediction_type', 'rescale_betas_zero_snr', 'dynamic_thresholding_ratio'} was not found in config. Values will be initialized to default values.
# 06/26/2026 23:43:32 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/tokenizer/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 06/26/2026 23:43:32 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/tokenizer/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 06/26/2026 23:43:32 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/tokenizer%2Ftokenizer_config.json "HTTP/1.1 200 OK"
# 06/26/2026 23:43:32 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/tokenizer%2Ftokenizer_config.json "HTTP/1.1 200 OK"
# tokenizer_config.json: 100% 806/806 [00:00<00:00, 2.39MB/s]
# 06/26/2026 23:43:32 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/models/runwayml/stable-diffusion-v1-5/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 307 Temporary Redirect"
# 06/26/2026 23:43:33 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/models/stable-diffusion-v1-5/stable-diffusion-v1-5/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# 06/26/2026 23:43:33 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/models/runwayml/stable-diffusion-v1-5/tree/main?recursive=true&expand=false "HTTP/1.1 307 Temporary Redirect"
# 06/26/2026 23:43:33 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/models/stable-diffusion-v1-5/stable-diffusion-v1-5/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# 06/26/2026 23:43:33 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/tokenizer/vocab.json "HTTP/1.1 307 Temporary Redirect"
# 06/26/2026 23:43:33 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/tokenizer/vocab.json "HTTP/1.1 307 Temporary Redirect"
# 06/26/2026 23:43:33 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/tokenizer%2Fvocab.json "HTTP/1.1 200 OK"
# 06/26/2026 23:43:33 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/tokenizer%2Fvocab.json "HTTP/1.1 200 OK"
# vocab.json: 100% 1.06M/1.06M [00:00<00:00, 57.7MB/s]
# 06/26/2026 23:43:33 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/tokenizer/merges.txt "HTTP/1.1 307 Temporary Redirect"
# 06/26/2026 23:43:33 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/tokenizer/merges.txt "HTTP/1.1 307 Temporary Redirect"
# 06/26/2026 23:43:33 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/tokenizer%2Fmerges.txt "HTTP/1.1 200 OK"
# 06/26/2026 23:43:33 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/tokenizer%2Fmerges.txt "HTTP/1.1 200 OK"
# merges.txt: 100% 525k/525k [00:00<00:00, 115MB/s]
# 06/26/2026 23:43:33 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/tokenizer/tokenizer.json "HTTP/1.1 307 Temporary Redirect"
# 06/26/2026 23:43:33 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/tokenizer/tokenizer.json "HTTP/1.1 404 Not Found"
# 06/26/2026 23:43:33 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/tokenizer/added_tokens.json "HTTP/1.1 307 Temporary Redirect"
# 06/26/2026 23:43:33 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/tokenizer/added_tokens.json "HTTP/1.1 404 Not Found"
# 06/26/2026 23:43:33 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/tokenizer/special_tokens_map.json "HTTP/1.1 307 Temporary Redirect"
# 06/26/2026 23:43:34 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/tokenizer/special_tokens_map.json "HTTP/1.1 307 Temporary Redirect"
# 06/26/2026 23:43:34 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/tokenizer%2Fspecial_tokens_map.json "HTTP/1.1 200 OK"
# 06/26/2026 23:43:34 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/tokenizer%2Fspecial_tokens_map.json "HTTP/1.1 200 OK"
# special_tokens_map.json: 100% 472/472 [00:00<00:00, 3.30MB/s]
# 06/26/2026 23:43:34 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/tokenizer/chat_template.jinja "HTTP/1.1 307 Temporary Redirect"
# 06/26/2026 23:43:34 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/tokenizer/chat_template.jinja "HTTP/1.1 404 Not Found"
# 06/26/2026 23:43:34 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/text_encoder/config.json "HTTP/1.1 307 Temporary Redirect"
# 06/26/2026 23:43:34 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/text_encoder/config.json "HTTP/1.1 307 Temporary Redirect"
# 06/26/2026 23:43:34 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/text_encoder%2Fconfig.json "HTTP/1.1 200 OK"
# 06/26/2026 23:43:34 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/text_encoder%2Fconfig.json "HTTP/1.1 200 OK"
# config.json: 100% 617/617 [00:00<00:00, 4.25MB/s]
# 06/26/2026 23:43:34 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/text_encoder/adapter_config.json "HTTP/1.1 307 Temporary Redirect"
# 06/26/2026 23:43:34 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/text_encoder/adapter_config.json "HTTP/1.1 404 Not Found"
# 06/26/2026 23:43:34 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/text_encoder/config.json "HTTP/1.1 307 Temporary Redirect"
# 06/26/2026 23:43:34 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/text_encoder/config.json "HTTP/1.1 307 Temporary Redirect"
# 06/26/2026 23:43:34 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/text_encoder%2Fconfig.json "HTTP/1.1 200 OK"
# 06/26/2026 23:43:34 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/text_encoder/model.safetensors "HTTP/1.1 307 Temporary Redirect"
# 06/26/2026 23:43:34 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/text_encoder/model.safetensors "HTTP/1.1 302 Found"
# text_encoder/model.safetensors: 100% 492M/492M [00:03<00:00, 138MB/s]
# Loading weights: 100% 196/196 [00:00<00:00, 5234.57it/s]
# 06/26/2026 23:43:38 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/vae/config.json "HTTP/1.1 307 Temporary Redirect"
# 06/26/2026 23:43:39 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/vae/config.json "HTTP/1.1 307 Temporary Redirect"
# 06/26/2026 23:43:39 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae%2Fconfig.json "HTTP/1.1 200 OK"
# 06/26/2026 23:43:39 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae%2Fconfig.json "HTTP/1.1 200 OK"
# config.json: 100% 547/547 [00:00<00:00, 3.58MB/s]
# 06/26/2026 23:43:39 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae/diffusion_pytorch_model.safetensors.index.json "HTTP/1.1 307 Temporary Redirect"
# 06/26/2026 23:43:39 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae/diffusion_pytorch_model.safetensors.index.json "HTTP/1.1 404 Not Found"
# 06/26/2026 23:43:39 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae/diffusion_pytorch_model.safetensors "HTTP/1.1 307 Temporary Redirect"
# 06/26/2026 23:43:39 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae/diffusion_pytorch_model.safetensors "HTTP/1.1 302 Found"
# vae/diffusion_pytorch_model.safetensors: 100% 335M/335M [00:02<00:00, 129MB/s]
# {'latents_mean', 'force_upcast', 'mid_block_add_attention', 'latents_std', 'use_post_quant_conv', 'scaling_factor', 'shift_factor', 'use_quant_conv'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at runwayml/stable-diffusion-v1-5.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# 06/26/2026 23:43:42 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/unet/config.json "HTTP/1.1 307 Temporary Redirect"
# 06/26/2026 23:43:42 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/unet/config.json "HTTP/1.1 307 Temporary Redirect"
# 06/26/2026 23:43:42 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/unet%2Fconfig.json "HTTP/1.1 200 OK"
# 06/26/2026 23:43:42 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/unet%2Fconfig.json "HTTP/1.1 200 OK"
# config.json: 100% 743/743 [00:00<00:00, 3.34MB/s]
# 06/26/2026 23:43:42 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/unet/diffusion_pytorch_model.safetensors.index.json "HTTP/1.1 307 Temporary Redirect"
# 06/26/2026 23:43:42 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/unet/diffusion_pytorch_model.safetensors.index.json "HTTP/1.1 404 Not Found"
# 06/26/2026 23:43:42 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/unet/diffusion_pytorch_model.safetensors "HTTP/1.1 307 Temporary Redirect"
# 06/26/2026 23:43:42 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/unet/diffusion_pytorch_model.safetensors "HTTP/1.1 302 Found"
# unet/diffusion_pytorch_model.safetensors: 100% 3.44G/3.44G [00:49<00:00, 69.2MB/s]
# {'reverse_transformer_layers_per_block', 'resnet_skip_time_act', 'time_cond_proj_dim', 'timestep_post_act', 'conv_out_kernel', 'encoder_hid_dim_type', 'time_embedding_type', 'projection_class_embeddings_input_dim', 'class_embed_type', 'transformer_layers_per_block', 'only_cross_attention', 'addition_embed_type', 'cross_attention_norm', 'time_embedding_dim', 'encoder_hid_dim', 'num_attention_heads', 'resnet_out_scale_factor', 'use_linear_projection', 'conv_in_kernel', 'addition_time_embed_dim', 'num_class_embeds', 'dropout', 'time_embedding_act_fn', 'resnet_time_scale_shift', 'attention_type', 'upcast_attention', 'mid_block_type', 'dual_cross_attention', 'addition_embed_type_num_heads', 'class_embeddings_concat', 'mid_block_only_cross_attention'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing UNet2DConditionModel.
#
# All the weights of UNet2DConditionModel were initialized from the model checkpoint at runwayml/stable-diffusion-v1-5.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use UNet2DConditionModel for predictions without further training.
# Resolving data files: 100% 103/103 [00:00<00:00, 25678.39it/s]
# Downloading data: 100% 100/100 [00:00<00:00, 31973.65files/s]
# Generating train split: 100 examples [00:00, 3717.46 examples/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# 06/26/2026 23:44:50 - INFO - __main__ - [RANK 0] ***** Running training *****
# 06/26/2026 23:44:50 - INFO - __main__ - [RANK 0]   Num examples = 100
# 06/26/2026 23:44:50 - INFO - __main__ - [RANK 0]   Num Epochs = 40
# 06/26/2026 23:44:50 - INFO - __main__ - [RANK 0]   Instantaneous batch size per device = 1
# 06/26/2026 23:44:50 - INFO - __main__ - [RANK 0]   Total train batch size (w. parallel, distributed & accumulation) = 4
# 06/26/2026 23:44:50 - INFO - __main__ - [RANK 0]   Gradient Accumulation steps = 4
# 06/26/2026 23:44:50 - INFO - __main__ - [RANK 0]   Total optimization steps = 1000
# Steps:   0% 0/1000 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:432: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# Steps:  50% 500/1000 [13:01<13:24,  1.61s/it, lr=5.02e-5, step_loss=0.00687]06/26/2026 23:57:52 - INFO - accelerate.accelerator - [RANK 0] Saving current state to /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank8/checkpoint-500
# Model weights saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank8/checkpoint-500/pytorch_lora_weights.safetensors
# 06/26/2026 23:57:52 - INFO - accelerate.checkpointing - [RANK 0] Optimizer state saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank8/checkpoint-500/optimizer.bin
# 06/26/2026 23:57:52 - INFO - accelerate.checkpointing - [RANK 0] Scheduler state saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank8/checkpoint-500/scheduler.bin
# 06/26/2026 23:57:52 - INFO - accelerate.checkpointing - [RANK 0] Sampler state for dataloader 0 saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank8/checkpoint-500/sampler.bin
# 06/26/2026 23:57:52 - INFO - accelerate.checkpointing - [RANK 0] Gradient scaler state saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank8/checkpoint-500/scaler.pt
# 06/26/2026 23:57:52 - INFO - accelerate.checkpointing - [RANK 0] Random states saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank8/checkpoint-500/random_states_0.pkl
# 06/26/2026 23:57:52 - INFO - __main__ - [RANK 0] Saved state to /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank8/checkpoint-500
# Steps: 100% 1000/1000 [26:06<00:00,  1.56s/it, lr=2.47e-10, step_loss=0.0495]06/27/2026 00:10:57 - INFO - accelerate.accelerator - [RANK 0] Saving current state to /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank8/checkpoint-1000
# Model weights saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank8/checkpoint-1000/pytorch_lora_weights.safetensors
# 06/27/2026 00:10:58 - INFO - accelerate.checkpointing - [RANK 0] Optimizer state saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank8/checkpoint-1000/optimizer.bin
# 06/27/2026 00:10:58 - INFO - accelerate.checkpointing - [RANK 0] Scheduler state saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank8/checkpoint-1000/scheduler.bin
# 06/27/2026 00:10:58 - INFO - accelerate.checkpointing - [RANK 0] Sampler state for dataloader 0 saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank8/checkpoint-1000/sampler.bin
# 06/27/2026 00:10:58 - INFO - accelerate.checkpointing - [RANK 0] Gradient scaler state saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank8/checkpoint-1000/scaler.pt
# 06/27/2026 00:10:58 - INFO - accelerate.checkpointing - [RANK 0] Random states saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank8/checkpoint-1000/random_states_0.pkl
# 06/27/2026 00:10:58 - INFO - __main__ - [RANK 0] Saved state to /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank8/checkpoint-1000
# Steps: 100% 1000/1000 [26:07<00:00,  1.56s/it, lr=0, step_loss=0.429]        Model weights saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank8/pytorch_lora_weights.safetensors
# Steps: 100% 1000/1000 [26:07<00:00,  1.57s/it, lr=0, step_loss=0.429]

# %%
# Célula 4B: CONFIGURAÇÃO B (Rank 32) - Alta Fidelidade de Detalhes
# !accelerate launch diffusers/examples/text_to_image/train_text_to_image_lora.py \
  --pretrained_model_name_or_path="runwayml/stable-diffusion-v1-5" \
  --dataset_name="/content/atelie-generativo-estilo-pixel-art/dataset" \
  --dataloader_num_workers=8 \
  --resolution=512 \
  --center_crop \
  --random_flip \
  --train_batch_size=1 \
  --gradient_accumulation_steps=4 \
  --max_train_steps=1500 \
  --learning_rate=1e-04 \
  --max_grad_norm=1 \
  --lr_scheduler="cosine" \
  --lr_warmup_steps=0 \
  --output_dir="/content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32" \
  --checkpointing_steps=500 \
  --seed=42 \
  --rank=32 \
  --mixed_precision="fp16" \
  --enable_xformers_memory_efficient_attention
# Out:
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Unable to import `torchao` Tensor objects. This may affect loading checkpoints serialized with `torchao`
# Flax classes are deprecated and will be removed in Diffusers v0.40.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v0.40.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# 06/27/2026 01:00:05 - INFO - __main__ - [RANK 0] Distributed environment: DistributedType.NO
# Num processes: 1
# Process index: 0
# Local process index: 0
# Device: cuda
#
# Mixed precision type: fp16
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py:205: UserWarning: The `local_dir_use_symlinks` argument is deprecated and ignored in `hf_hub_download`. Downloading to a local directory does not use symlinks anymore.
#   warnings.warn(
# 06/27/2026 01:00:05 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/scheduler/scheduler_config.json "HTTP/1.1 307 Temporary Redirect"
# 06/27/2026 01:00:05 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/scheduler/scheduler_config.json "HTTP/1.1 307 Temporary Redirect"
# 06/27/2026 01:00:05 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/scheduler%2Fscheduler_config.json "HTTP/1.1 200 OK"
# {'rescale_betas_zero_snr', 'dynamic_thresholding_ratio', 'thresholding', 'timestep_spacing', 'variance_type', 'sample_max_value', 'clip_sample_range', 'prediction_type'} was not found in config. Values will be initialized to default values.
# 06/27/2026 01:00:06 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/tokenizer/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 06/27/2026 01:00:06 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/tokenizer/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 06/27/2026 01:00:06 - WARNING - huggingface_hub.utils._http - Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 06/27/2026 01:00:06 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/tokenizer%2Ftokenizer_config.json "HTTP/1.1 200 OK"
# 06/27/2026 01:00:06 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/models/runwayml/stable-diffusion-v1-5/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 307 Temporary Redirect"
# 06/27/2026 01:00:06 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/models/stable-diffusion-v1-5/stable-diffusion-v1-5/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# 06/27/2026 01:00:06 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/models/runwayml/stable-diffusion-v1-5/tree/main?recursive=true&expand=false "HTTP/1.1 307 Temporary Redirect"
# 06/27/2026 01:00:06 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/models/stable-diffusion-v1-5/stable-diffusion-v1-5/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# 06/27/2026 01:00:06 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/text_encoder/config.json "HTTP/1.1 307 Temporary Redirect"
# 06/27/2026 01:00:06 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/text_encoder/config.json "HTTP/1.1 307 Temporary Redirect"
# 06/27/2026 01:00:06 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/text_encoder%2Fconfig.json "HTTP/1.1 200 OK"
# 06/27/2026 01:00:06 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/text_encoder/config.json "HTTP/1.1 307 Temporary Redirect"
# 06/27/2026 01:00:07 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/text_encoder/config.json "HTTP/1.1 307 Temporary Redirect"
# 06/27/2026 01:00:07 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/text_encoder%2Fconfig.json "HTTP/1.1 200 OK"
# 06/27/2026 01:00:07 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/text_encoder/model.safetensors "HTTP/1.1 307 Temporary Redirect"
# 06/27/2026 01:00:07 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/text_encoder/model.safetensors "HTTP/1.1 302 Found"
# Loading weights: 100% 196/196 [00:00<00:00, 787.85it/s]
# 06/27/2026 01:00:07 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/vae/config.json "HTTP/1.1 307 Temporary Redirect"
# 06/27/2026 01:00:07 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/vae/config.json "HTTP/1.1 307 Temporary Redirect"
# 06/27/2026 01:00:07 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae%2Fconfig.json "HTTP/1.1 200 OK"
# 06/27/2026 01:00:07 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae/diffusion_pytorch_model.safetensors.index.json "HTTP/1.1 307 Temporary Redirect"
# 06/27/2026 01:00:08 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae/diffusion_pytorch_model.safetensors.index.json "HTTP/1.1 404 Not Found"
# {'scaling_factor', 'mid_block_add_attention', 'use_post_quant_conv', 'force_upcast', 'shift_factor', 'latents_mean', 'latents_std', 'use_quant_conv'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at runwayml/stable-diffusion-v1-5.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# 06/27/2026 01:00:08 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/unet/config.json "HTTP/1.1 307 Temporary Redirect"
# 06/27/2026 01:00:08 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/unet/config.json "HTTP/1.1 307 Temporary Redirect"
# 06/27/2026 01:00:08 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/unet%2Fconfig.json "HTTP/1.1 200 OK"
# 06/27/2026 01:00:08 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/unet/diffusion_pytorch_model.safetensors.index.json "HTTP/1.1 307 Temporary Redirect"
# 06/27/2026 01:00:08 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/unet/diffusion_pytorch_model.safetensors.index.json "HTTP/1.1 404 Not Found"
# {'resnet_time_scale_shift', 'use_linear_projection', 'addition_embed_type', 'upcast_attention', 'mid_block_type', 'only_cross_attention', 'resnet_out_scale_factor', 'dropout', 'mid_block_only_cross_attention', 'class_embed_type', 'conv_in_kernel', 'cross_attention_norm', 'encoder_hid_dim_type', 'transformer_layers_per_block', 'time_embedding_type', 'num_attention_heads', 'addition_time_embed_dim', 'resnet_skip_time_act', 'encoder_hid_dim', 'time_embedding_dim', 'reverse_transformer_layers_per_block', 'class_embeddings_concat', 'num_class_embeds', 'time_embedding_act_fn', 'attention_type', 'timestep_post_act', 'conv_out_kernel', 'addition_embed_type_num_heads', 'projection_class_embeddings_input_dim', 'time_cond_proj_dim', 'dual_cross_attention'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing UNet2DConditionModel.
#
# All the weights of UNet2DConditionModel were initialized from the model checkpoint at runwayml/stable-diffusion-v1-5.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use UNet2DConditionModel for predictions without further training.
# Resolving data files: 100% 103/103 [00:00<00:00, 93997.67it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# 06/27/2026 01:00:37 - INFO - __main__ - [RANK 0] ***** Running training *****
# 06/27/2026 01:00:37 - INFO - __main__ - [RANK 0]   Num examples = 100
# 06/27/2026 01:00:37 - INFO - __main__ - [RANK 0]   Num Epochs = 60
# 06/27/2026 01:00:37 - INFO - __main__ - [RANK 0]   Instantaneous batch size per device = 1
# 06/27/2026 01:00:37 - INFO - __main__ - [RANK 0]   Total train batch size (w. parallel, distributed & accumulation) = 4
# 06/27/2026 01:00:37 - INFO - __main__ - [RANK 0]   Gradient Accumulation steps = 4
# 06/27/2026 01:00:37 - INFO - __main__ - [RANK 0]   Total optimization steps = 1500
# Steps:   0% 0/1500 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:432: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# Steps:  33% 500/1500 [13:15<26:07,  1.57s/it, lr=7.51e-5, step_loss=0.00612]06/27/2026 01:13:53 - INFO - accelerate.accelerator - [RANK 0] Saving current state to /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/checkpoint-500
# Model weights saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/checkpoint-500/pytorch_lora_weights.safetensors
# 06/27/2026 01:13:53 - INFO - accelerate.checkpointing - [RANK 0] Optimizer state saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/checkpoint-500/optimizer.bin
# 06/27/2026 01:13:53 - INFO - accelerate.checkpointing - [RANK 0] Scheduler state saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/checkpoint-500/scheduler.bin
# 06/27/2026 01:13:53 - INFO - accelerate.checkpointing - [RANK 0] Sampler state for dataloader 0 saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/checkpoint-500/sampler.bin
# 06/27/2026 01:13:53 - INFO - accelerate.checkpointing - [RANK 0] Gradient scaler state saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/checkpoint-500/scaler.pt
# 06/27/2026 01:13:53 - INFO - accelerate.checkpointing - [RANK 0] Random states saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/checkpoint-500/random_states_0.pkl
# 06/27/2026 01:13:53 - INFO - __main__ - [RANK 0] Saved state to /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/checkpoint-500
# Steps:  67% 1000/1500 [26:31<13:33,  1.63s/it, lr=2.51e-5, step_loss=0.0798]06/27/2026 01:27:08 - INFO - accelerate.accelerator - [RANK 0] Saving current state to /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/checkpoint-1000
# Model weights saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/checkpoint-1000/pytorch_lora_weights.safetensors
# 06/27/2026 01:27:09 - INFO - accelerate.checkpointing - [RANK 0] Optimizer state saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/checkpoint-1000/optimizer.bin
# 06/27/2026 01:27:09 - INFO - accelerate.checkpointing - [RANK 0] Scheduler state saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/checkpoint-1000/scheduler.bin
# 06/27/2026 01:27:09 - INFO - accelerate.checkpointing - [RANK 0] Sampler state for dataloader 0 saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/checkpoint-1000/sampler.bin
# 06/27/2026 01:27:09 - INFO - accelerate.checkpointing - [RANK 0] Gradient scaler state saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/checkpoint-1000/scaler.pt
# 06/27/2026 01:27:09 - INFO - accelerate.checkpointing - [RANK 0] Random states saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/checkpoint-1000/random_states_0.pkl
# 06/27/2026 01:27:09 - INFO - __main__ - [RANK 0] Saved state to /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/checkpoint-1000
# Steps: 100% 1500/1500 [39:44<00:00,  1.59s/it, lr=1.1e-10, step_loss=0.00919]06/27/2026 01:40:22 - INFO - accelerate.accelerator - [RANK 0] Saving current state to /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/checkpoint-1500
# Model weights saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/checkpoint-1500/pytorch_lora_weights.safetensors
# 06/27/2026 01:40:22 - INFO - accelerate.checkpointing - [RANK 0] Optimizer state saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/checkpoint-1500/optimizer.bin
# 06/27/2026 01:40:22 - INFO - accelerate.checkpointing - [RANK 0] Scheduler state saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/checkpoint-1500/scheduler.bin
# 06/27/2026 01:40:22 - INFO - accelerate.checkpointing - [RANK 0] Sampler state for dataloader 0 saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/checkpoint-1500/sampler.bin
# 06/27/2026 01:40:22 - INFO - accelerate.checkpointing - [RANK 0] Gradient scaler state saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/checkpoint-1500/scaler.pt
# 06/27/2026 01:40:22 - INFO - accelerate.checkpointing - [RANK 0] Random states saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/checkpoint-1500/random_states_0.pkl
# 06/27/2026 01:40:22 - INFO - __main__ - [RANK 0] Saved state to /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/checkpoint-1500
# Steps: 100% 1500/1500 [39:45<00:00,  1.59s/it, lr=0, step_loss=0.102]        Model weights saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/pytorch_lora_weights.safetensors
# Steps: 100% 1500/1500 [39:45<00:00,  1.59s/it, lr=0, step_loss=0.102]

# %% [markdown]
# **5 - Inferência e Validação Visual**
# > Após o treino, os arquivos *.safetensors* dos seus LoRAs estarão a salvo no seu Google Drive. Use esta célula para carregar o modelo treinado e testar se ele aprendeu o estilo!

# %%
# Célula 5: Teste de Geração Visual
import torch
from diffusers import StableDiffusionPipeline
from IPython.display import display

# Carrega o modelo base e envia para a GPU
pipe = StableDiffusionPipeline.from_pretrained("runwayml/stable-diffusion-v1-5", torch_dtype=torch.float16)
pipe.to("cuda")

# Injeta os pesos do LoRA que você deseja testar (Ex: Rank 32)
caminho_do_lora = "/content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32"
pipe.load_lora_weights(caminho_do_lora)

# Prompt para geração
prompt = "estilo_pixel_art, cena em pixel art com fazenda, estufa, plantações, espantalhos e personagem agricultor."

print("🎨 Sintetizando imagem no espaço latente...")
imagem = pipe(prompt, num_inference_steps=200, guidance_scale=9.0).images[0]

print("\n✨ Resultado da Inferência:")
display(imagem)
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/396 [00:00<?, ?it/s]
