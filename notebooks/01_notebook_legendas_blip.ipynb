# %% [markdown]
# **1: Preparação do Ambiente e Clonagem do Repositório**

# %%
# Célula 1: Instalação de dependências e clonagem do GitHub
# !pip -q install transformers pillow torch torchvision

import os

# Clona o repositório diretamente para o Colab
# !git clone https://github.com/Thiagofariasl/atelie-generativo-estilo-pixel-art.git

# !pip install -q deep-translator

# Define o caminho
dataset_path = "/content/atelie-generativo-estilo-pixel-art/dataset/images"
output_file = os.path.join(dataset_path, "legendas.txt")

print(f"Repositório clonado! Pasta do dataset: {dataset_path}")
# Out:
# Cloning into 'atelie-generativo-estilo-pixel-art'...
# remote: Enumerating objects: 374, done.
# remote: Counting objects: 100% (69/69), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 374 (delta 42), reused 24 (delta 15), pack-reused 305 (from 1)
# Receiving objects: 100% (374/374), 26.34 MiB | 16.89 MiB/s, done.
# Resolving deltas: 100% (134/134), done.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 3.3 MB/s eta 0:00:00
# Repositório clonado! Pasta do dataset: /content/atelie-generativo-estilo-pixel-art/dataset/images

# %% [markdown]
# **2: Carregamento do Modelo BLIP**

# %%
# Célula 2: Inicialização do BLIP
from transformers import BlipProcessor, BlipForConditionalGeneration
import torch

# Verifica se a GPU (CUDA) está disponível
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Usando processamento em: {device.upper()}")

# Carrega o processador e o modelo
print("Carregando o modelo BLIP (isso pode levar alguns instantes)...")
proc = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-base")
blip = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base").to(device)
print("Modelo carregado com sucesso!")
# Out:
# Usando processamento em: CUDA
# Carregando o modelo BLIP (isso pode levar alguns instantes)...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# preprocessor_config.json:   0%|          | 0.00/287 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/4.56k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/506 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Modelo carregado com sucesso!

# %% [markdown]
# **3: Processamento em Lote (Batch) e Geração do "legendas.txt"**

# %%
# Célula 3: Geração das legendas
import os
from PIL import Image
from transformers import BlipProcessor, BlipForConditionalGeneration
from deep_translator import GoogleTranslator # Nova importação

# Inicialização do Tradutor
tradutor = GoogleTranslator(source='en', target='pt')

trigger_word = "estilo_pixel_art,"

# Lista todas as imagens na pasta (suporta jpg e png)
imagens_validas = ('.jpg', '.jpeg', '.png')
lista_imagens = [f for f in os.listdir(dataset_path) if f.lower().endswith(imagens_validas)]

if len(lista_imagens) == 0:
    print("Nenhuma imagem encontrada na pasta dataset. Verifique se elas já foram atualizadas no GitHub.")
else:
    print(f"Iniciando o processamento de {len(lista_imagens)} imagens...\n")

    # Abre o arquivo legendas.txt em modo de escrita
    with open(output_file, "w", encoding="utf-8") as f:
        for img_name in lista_imagens:
            img_path = os.path.join(dataset_path, img_name)

            # Carrega a imagem
            img = Image.open(img_path).convert('RGB')

            # Geração original em inglês pelo BLIP
            out = blip.generate(**proc(img, return_tensors="pt").to("cuda"), max_new_tokens=40)
            legenda_ingles = proc.decode(out[0], skip_special_tokens=True)

            # Tradução para pt-BR (Stable Diffusion v1.5 - vocabulário muito mais rico em inglês)
            legenda_ptbr = tradutor.translate(legenda_ingles)

            # Adicionando a trigger word na frente da legenda traduzida
            legenda_final = f"{trigger_word} {legenda_ptbr}"

            # Salvando no arquivo com a formatação exigida
            linha = f"{img_name}: {legenda_final}\n"
            f.write(linha)

            print(f"✅ {img_name} -> {legenda_final}")

    print(f"\n🎉 Arquivo 'legendas.txt' gerado com sucesso em: {output_file}")
# Out:
# Iniciando o processamento de 100 imagens...
#
# ✅ jirbyart-2.png -> estilo_pixel_art, uma captura de tela de uma casa com piscina e uma pequena piscina
# ✅ retroquest-3.png -> estilo_pixel_art, um mapa de pixels com uma pequena ilha no meio
# ✅ stingraystudio-2.png -> estilo_pixel_art, um mapa de pixels com uma pequena ilha e uma pequena vila
# ✅ szadiart-1.png -> estilo_pixel_art, um mapa de uma pequena cidade com uma pequena casa
# ✅ simflz-3.png -> estilo_pixel_art, um mapa com uma pequena vila e árvores
# ✅ anokolisa-11.png -> estilo_pixel_art, uma pequena casa no meio de uma floresta
# ✅ simflz-6.png -> estilo_pixel_art, um mapa de pixels com uma fazenda e um lago
# ✅ mr-pixzels-1.png -> estilo_pixel_art, uma captura de tela de uma floresta com um caminho e árvores
# ✅ nulltale-3.png -> estilo_pixel_art, um fundo escuro com um ramo de flores
# ✅ ninjikin-1.png -> estilo_pixel_art, um pixel pixel no escuro
# ✅ nura-pixel-2.png -> estilo_pixel_art, um pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel
# ✅ crumpaloo-4.png -> estilo_pixel_art, um pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel
# ✅ nura-pixel-1.png -> estilo_pixel_art, um pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel
# ✅ gfragger-2.png -> estilo_pixel_art, uma captura de tela de uma cidade com muitos edifícios
# ✅ hoyb-2.png -> estilo_pixel_art, uma captura de tela de uma vila com árvores e edifícios
# ✅ pixel-boy-1.png -> estilo_pixel_art, uma captura de tela de uma cidade com árvores e edifícios
# ✅ jik-a-4-2.png -> estilo_pixel_art, uma imagem em estilo pixel de uma mulher sentada em uma cadeira
# ✅ jirbyart-4.png -> estilo_pixel_art, um pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel
# ✅ hoyb-1.png -> estilo_pixel_art, uma captura de tela de uma cidade com muitas casas
# ✅ ventilatore-2.png -> estilo_pixel_art, um mapa de uma pequena cidade com muitas árvores
# ✅ merchant-shade-2.png -> estilo_pixel_art, uma captura de tela de um grupo de pessoas em uma floresta
# ✅ ansimuz-1.png -> estilo_pixel_art, um mapa da ilha
# ✅ largatachi-1.png -> estilo_pixel_art, um mapa de uma floresta com um pequeno lago e árvores
# ✅ nura-pixel-3.png -> estilo_pixel_art, uma captura de tela de um castelo com uma torre e uma porta
# ✅ ventilatore-4.png -> estilo_pixel_art, um mapa de uma vila com um rio e uma pequena ilha
# ✅ ninjikin-3.png -> estilo_pixel_art, uma imagem em estilo pixel de um homem com barba
# ✅ marceles-1.png -> estilo_pixel_art, um mapa de um hospital com um hospital e um hospital
# ✅ petricakegames-1.png -> estilo_pixel_art, uma captura de tela de um jogo com fundo vermelho
# ✅ cainos-3.png -> estilo_pixel_art, o mapa do jogo, com a localização da vila
# ✅ glionox-2.png -> estilo_pixel_art, uma captura de tela de um deserto com um pequeno rio e um pequeno riacho
# ✅ game-endeavor-1.png -> estilo_pixel_art, um mapa de uma pequena cidade com um lago e uma pequena casa
# ✅ anokolisa-10.png -> estilo_pixel_art, uma captura de tela de uma pequena cidade com um cavalo e um cavalo
# ✅ arex-v-1.png -> estilo_pixel_art, a lenda de Zeo
# ✅ limezu-1.png -> estilo_pixel_art, planta de uma casa com sala e cozinha
# ✅ ventilatore-3.png -> estilo_pixel_art, um mapa de uma vila com muitas árvores
# ✅ stardustdevelopment-2.png -> estilo_pixel_art, um pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel
# ✅ toivio-1.png -> estilo_pixel_art, o layout do jogo, com uma parede de tijolos e uma pequena sala
# ✅ limezu-kitchen-1.png -> estilo_pixel_art, a planta baixa do apartamento
# ✅ hoyb-3.png -> estilo_pixel_art, uma captura de tela de uma casa cercada por muitas caveiras
# ✅ simflz-1.png -> estilo_pixel_art, um mapa de pixels com uma pequena vila e uma pequena casa
# ✅ gfragger-3.png -> estilo_pixel_art, uma captura de tela de uma vila com um cavalo e um homem
# ✅ jirbyart-3.png -> estilo_pixel_art, um quarto com uma cama e uma estante
# ✅ largatachi-3.png -> estilo_pixel_art, um mapa com um pequeno lago e árvores
# ✅ anokolisa-6.png -> estilo_pixel_art, uma captura de tela de uma floresta com árvores e pedras
# ✅ mattwalkden-1.png -> estilo_pixel_art, o mapa do jogo, com vários locais e localizações diferentes
# ✅ retroquest-2.png -> estilo_pixel_art, um pixel pixel com um rio e uma ponte
# ✅ pixel-boy-3.png -> estilo_pixel_art, um mapa de pixels com uma pequena cidade e árvores
# ✅ nulltale-1.png -> estilo_pixel_art, um pixel pixel art
# ✅ arex-v-3.png -> estilo_pixel_art, a lenda de Zeria
# ✅ marceles-5.png -> estilo_pixel_art, uma captura de tela de um castelo com um castelo ao fundo
# ✅ retroquest-1.png -> estilo_pixel_art, uma captura de tela de uma floresta com um caminho e árvores
# ✅ marceles-6.png -> estilo_pixel_art, uma captura de tela de um castelo com uma torre e uma torre
# ✅ crumpaloo-3.png -> estilo_pixel_art, um pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel
# ✅ marceles-2.png -> estilo_pixel_art, as primeiras telas do jogo, mostrando o interior e a cozinha
# ✅ simflz-5.png -> estilo_pixel_art, uma imagem pixelizada de uma tela verde com um porco rosa
# ✅ jirbyart-5.png -> estilo_pixel_art, um pixel pixel art
# ✅ jirbyart-1.png -> estilo_pixel_art, uma casa de pixel na floresta
# ✅ marie-pepo-1.png -> estilo_pixel_art, uma captura de tela de um parque com árvores e um lago
# ✅ pingupollas-2.png -> estilo_pixel_art, uma captura de tela de uma sala com uma mesa e uma mesa com um computador
# ✅ jik-a-4-1.png -> estilo_pixel_art, um papel de parede estilo pixel com palmeiras e uma porta
# ✅ stingraystudio-1.png -> estilo_pixel_art, um mapa de pixels com uma pequena árvore e uma pequena casa
# ✅ anokolisa-4.png -> estilo_pixel_art, as telas do jogo são todas diferentes, mas são diferentes
# ✅ limezu-4.png -> estilo_pixel_art, uma sala com um monte de objetos e um monte de objetos
# ✅ pixel-poem-1.png -> estilo_pixel_art, um pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel pixel
# ✅ gfragger-1.png -> estilo_pixel_art, uma captura de tela de um castelo cercado por árvores
# ✅ jeff-1.png -> estilo_pixel_art, uma captura de tela de um campo com algumas plantas
# ✅ largatachi-4.png -> estilo_pixel_art, um mapa de pixels com uma pequena vila e uma pequena vila
# ✅ cainos-4.png -> estilo_pixel_art, um mapa de uma pequena cidade com alguns edifícios
# ✅ marceles-4.png -> estilo_pixel_art, uma captura de tela de um castelo com uma torre e um portão
# ✅ nulltale-2.png -> estilo_pixel_art, as telas do jogo são todas diferentes, mas são diferentes
# ✅ anokolisa-3.png -> estilo_pixel_art, uma sala com vários ambientes e móveis diferentes
# ✅ limezu-5.png -> estilo_pixel_art, planta do jogo, com sala e área de estar
# ✅ devrenan-1.png -> estilo_pixel_art, uma captura de tela de uma masmorra
# ✅ rolff-1.png -> estilo_pixel_art, um quarto com um gato e uma estante
# ✅ anokolisa-5.png -> estilo_pixel_art, uma captura de tela de uma floresta com uma pequena casa no meio
# ✅ limezu-3.png -> estilo_pixel_art, a sala do jogo, com chão e paredes
# ✅ crumpaloo-1.png -> estilo_pixel_art, um mapa de pixels com um homem de terno e chapéu
# ✅ stardustdevelopment-1.png -> estilo_pixel_art, uma captura de tela de uma sala com uma porta e uma janela
# ✅ crumpaloo-6.png -> estilo_pixel_art, as telas do jogo são muito simples, mas são muito simples
# ✅ arex-v-2.png -> estilo_pixel_art, a lenda de Zeria
# ✅ largatachi-2.png -> estilo_pixel_art, um mapa de pixels com uma casa pequena e uma casa pequena
# ✅ limezu-2.png -> estilo_pixel_art, um pixel pixel art de uma sala com um gato e um cachorro
# ✅ simflz-4.png -> estilo_pixel_art, um pixel pixel em um fundo verde
# ✅ merchant-shade-1.png -> estilo_pixel_art, uma captura de tela de uma pequena cidade com árvores e um rio
# ✅ anokolisa-2.png -> estilo_pixel_art, a vila do jogo, com uma casinha e um pequeno lago
# ✅ crumpaloo-5.png -> estilo_pixel_art, um jogo de pixel pixel com um pequeno castelo
# ✅ simflz-2.png -> estilo_pixel_art, uma captura de tela de um castelo com piso de pedra
# ✅ crumpaloo-2.png -> estilo_pixel_art, a lenda de Zeom
# ✅ pingupollas-1.png -> estilo_pixel_art, a masmorra captura de tela da masmorra
# ✅ szadiart-2.png -> estilo_pixel_art, um mapa de uma vila com um rio e uma pequena casa
# ✅ stardustdevelopment-3.png -> estilo_pixel_art, um pixel pixel art
# ✅ pingupollas-3.png -> estilo_pixel_art, uma captura de tela de uma masmorra
# ✅ glionox-1.png -> estilo_pixel_art, uma captura de tela de um deserto com palmeiras e um lago
# ✅ anokolisa-1.png -> estilo_pixel_art, uma pequena cidade com muitas árvores e edifícios
# ✅ ventilatore-5.png -> estilo_pixel_art, um mapa de um parque com árvores e edifícios
# ✅ pixel-poem-2.png -> estilo_pixel_art, uma captura de tela de uma masmorra masmorra masmorra masmorra masmorra masmorra masmorra masmorra masmorra masmorra masmorra masmorra masmorra
# ✅ cainos-2.png -> estilo_pixel_art, um mapa com um caminho de pedra e um caminho de pedra
# ✅ ilmenite-1.png -> estilo_pixel_art, o mapa do jogo, com um pequeno lago no meio
# ✅ ninjikin-2.png -> estilo_pixel_art, uma captura de tela de uma caverna com uma bola verde no meio
# ✅ pixel-boy-2.png -> estilo_pixel_art, uma captura de tela de um mapa com um mapa e um mapa
#
# 🎉 Arquivo 'legendas.txt' gerado com sucesso em: /content/atelie-generativo-estilo-pixel-art/dataset/images/legendas.txt

# %% [markdown]
# **4: Download Seguro para Revisão Humana**

# %%
# Célula 4: Download do arquivo
from google.colab import files

# Baixa o arquivo para a sua máquina
files.download(output_file)
print("Download iniciado. Revise as legendas manualmente antes de subir para o GitHub!")
# Out:
# Download iniciado. Revise as legendas manualmente antes de subir para o GitHub!
