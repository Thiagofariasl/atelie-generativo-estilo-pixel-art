# %% [markdown]
# # **Ateliê Generativo — Treinamento LoRA (Google Colab / GPU T4)**
#
# > Notebook-guia da Etapa 2. Treina o adaptador LoRA de pixel art 16 bits.
# Antes de começar: Runtime → Alterar tipo de runtime → GPUs (T4).

# %% [markdown]
# **1 - Infraestrutura, Otimização e Armazenamento Persistente**

# %%
# Célula 1: Montagem do Drive e Instalação do Ecossistema
from google.colab import drive
drive.mount('/content/drive')

import os
# Cria o diretório de destino no seu Google Drive
drive_path = "/content/drive/MyDrive/Atelie_Generativo_LoRA"
os.makedirs(drive_path, exist_ok=True)
print(f"📁 Pasta de salvamento criada em: {drive_path}")

# Instalação das bibliotecas com versões otimizadas para GPU T4
# !pip install -q -U transformers accelerate peft bitsandbytes datasets xformers torchao

# Instalação da biblioteca diffusers (cutting-edge)
# !pip install -q git+https://github.com/huggingface/diffusers.git

# Clonagem do repositório oficial da Hugging Face para acesso ao script de treinamento
# !git clone https://github.com/huggingface/diffusers.git
# Out:
# Mounted at /content/drive
# 📁 Pasta de salvamento criada em: /content/drive/MyDrive/Atelie_Generativo_LoRA
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 116.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 13.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 555.1/555.1 kB 47.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 111.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 121.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 MB 18.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for diffusers (pyproject.toml) ... done
# Cloning into 'diffusers'...
# remote: Enumerating objects: 126096, done.
# remote: Counting objects: 100% (164/164), done.
# remote: Compressing objects: 100% (140/140), done.
# remote: Total 126096 (delta 82), reused 30 (delta 22), pack-reused 125932 (from 2)
# Receiving objects: 100% (126096/126096), 99.42 MiB | 23.13 MiB/s, done.
# Resolving deltas: 100% (94073/94073), done.

# %% [markdown]
# **2 - Ingestão de Dados e Mapeamento de Caminhos**

# %%
# Célula 2: Download do Dataset e Construção do metadata.jsonl
import json

# Clona o repositório da equipe
# !git clone https://github.com/Thiagofariasl/atelie-generativo-estilo-pixel-art.git

# Definição dos caminhos base
dataset_dir = "/content/atelie-generativo-estilo-pixel-art/dataset"
txt_file = os.path.join(dataset_dir, "legendas.txt")
jsonl_file = os.path.join(dataset_dir, "metadata.jsonl")

# Lógica de conversão adaptada para a arquitetura do GitHub
# Transforma: "img_01.jpg: legenda" -> {"file_name": "images/img_01.jpg", "text": "legenda"}
with open(txt_file, 'r', encoding='utf-8') as f_in, open(jsonl_file, 'w', encoding='utf-8') as f_out:
    for linha in f_in:
        if ':' in linha:
            arquivo, legenda = linha.split(':', 1)

            # Adicionando o prefixo da subpasta para garantir que o Diffusers encontre a imagem
            caminho_relativo = f"images/{arquivo.strip()}"

            json_obj = {"file_name": caminho_relativo, "text": legenda.strip()}
            f_out.write(json.dumps(json_obj) + '\n')

print("✅ Dataset preparado! O arquivo metadata.jsonl mapeia corretamente a subpasta 'images/'.")
# Out:
# Cloning into 'atelie-generativo-estilo-pixel-art'...
# remote: Enumerating objects: 368, done.
# remote: Counting objects: 100% (63/63), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 368 (delta 38), reused 24 (delta 15), pack-reused 305 (from 1)
# Receiving objects: 100% (368/368), 26.34 MiB | 18.97 MiB/s, done.
# Resolving deltas: 100% (130/130), done.
# ✅ Dataset preparado! O arquivo metadata.jsonl mapeia corretamente a subpasta 'images/'.

# %% [markdown]
# **3 - Configuração do Accelerate**

# %%
# Célula 3: Configuração do hardware
from accelerate.utils import write_basic_config
write_basic_config()
print("🚀 Accelerate configurado para maximizar a eficiência da GPU T4!")
# Out:
# 🚀 Accelerate configurado para maximizar a eficiência da GPU T4!

# %% [markdown]
# **4 - O Treinamento Matemático (As Duas Configurações Exigidas)**
#
# > Execute a Célula 4A (Rank 8), aguarde terminar (pode levar 20-40 min dependendo do número de épocas/imagens).
#
# > Quando concluir, execute a Célula 4B (Rank 16).
#
# > Em seguida, execute a Célula 4C (Rank 32).

# %%
# Célula 4A: CONFIGURAÇÃO A (Rank 8) - Generalização de Estilo
# !accelerate launch diffusers/examples/text_to_image/train_text_to_image_lora.py \
  --pretrained_model_name_or_path="runwayml/stable-diffusion-v1-5" \
  --dataset_name="/content/atelie-generativo-estilo-pixel-art/dataset" \
  --dataloader_num_workers=8 \
  --resolution=512 \
  --center_crop \
  --random_flip \
  --train_batch_size=1 \
  --gradient_accumulation_steps=4 \
  --max_train_steps=1100 \
  --learning_rate=1e-04 \
  --max_grad_norm=1 \
  --lr_scheduler="cosine" \
  --lr_warmup_steps=0 \
  --output_dir="/content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank8" \
  --checkpointing_steps=500 \
  --seed=42 \
  --rank=8 \
  --mixed_precision="fp16" \
  --enable_xformers_memory_efficient_attention
# Out:
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Unable to import `torchao` Tensor objects. This may affect loading checkpoints serialized with `torchao`
# Flax classes are deprecated and will be removed in Diffusers v0.40.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v0.40.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# 07/05/2026 19:17:15 - INFO - __main__ - [RANK 0] Distributed environment: DistributedType.NO
# Num processes: 1
# Process index: 0
# Local process index: 0
# Device: cuda
#
# Mixed precision type: fp16
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py:205: UserWarning: The `local_dir_use_symlinks` argument is deprecated and ignored in `hf_hub_download`. Downloading to a local directory does not use symlinks anymore.
#   warnings.warn(
# 07/05/2026 19:17:15 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/agent-harnesses "HTTP/1.1 200 OK"
# 07/05/2026 19:17:16 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/scheduler/scheduler_config.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 19:17:16 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/scheduler/scheduler_config.json "HTTP/1.1 307 Temporary Redirect"
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 07/05/2026 19:17:16 - WARNING - huggingface_hub.utils._http - Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 07/05/2026 19:17:16 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/scheduler%2Fscheduler_config.json "HTTP/1.1 200 OK"
# 07/05/2026 19:17:16 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/scheduler%2Fscheduler_config.json "HTTP/1.1 200 OK"
# scheduler_config.json: 100% 308/308 [00:00<00:00, 1.35MB/s]
# {'thresholding', 'timestep_spacing', 'variance_type', 'prediction_type', 'sample_max_value', 'dynamic_thresholding_ratio', 'clip_sample_range', 'rescale_betas_zero_snr'} was not found in config. Values will be initialized to default values.
# 07/05/2026 19:17:16 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/tokenizer/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 19:17:16 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/tokenizer/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 19:17:16 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/tokenizer%2Ftokenizer_config.json "HTTP/1.1 200 OK"
# 07/05/2026 19:17:16 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/tokenizer%2Ftokenizer_config.json "HTTP/1.1 200 OK"
# tokenizer_config.json: 100% 806/806 [00:00<00:00, 3.38MB/s]
# 07/05/2026 19:17:17 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/models/runwayml/stable-diffusion-v1-5/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 19:17:17 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/models/stable-diffusion-v1-5/stable-diffusion-v1-5/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# 07/05/2026 19:17:17 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/models/runwayml/stable-diffusion-v1-5/tree/main?recursive=true&expand=false "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 19:17:17 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/models/stable-diffusion-v1-5/stable-diffusion-v1-5/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# 07/05/2026 19:17:18 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/tokenizer/vocab.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 19:17:18 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/tokenizer/vocab.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 19:17:18 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/tokenizer%2Fvocab.json "HTTP/1.1 200 OK"
# 07/05/2026 19:17:18 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/tokenizer%2Fvocab.json "HTTP/1.1 200 OK"
# vocab.json: 100% 1.06M/1.06M [00:00<00:00, 128MB/s]
# 07/05/2026 19:17:18 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/tokenizer/merges.txt "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 19:17:18 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/tokenizer/merges.txt "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 19:17:18 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/tokenizer%2Fmerges.txt "HTTP/1.1 200 OK"
# 07/05/2026 19:17:18 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/tokenizer%2Fmerges.txt "HTTP/1.1 200 OK"
# merges.txt: 100% 525k/525k [00:00<00:00, 120MB/s]
# 07/05/2026 19:17:19 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/tokenizer/tokenizer.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 19:17:19 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/tokenizer/tokenizer.json "HTTP/1.1 404 Not Found"
# 07/05/2026 19:17:19 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/tokenizer/added_tokens.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 19:17:19 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/tokenizer/added_tokens.json "HTTP/1.1 404 Not Found"
# 07/05/2026 19:17:19 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/tokenizer/special_tokens_map.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 19:17:20 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/tokenizer/special_tokens_map.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 19:17:20 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/tokenizer%2Fspecial_tokens_map.json "HTTP/1.1 200 OK"
# 07/05/2026 19:17:20 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/tokenizer%2Fspecial_tokens_map.json "HTTP/1.1 200 OK"
# special_tokens_map.json: 100% 472/472 [00:00<00:00, 3.51MB/s]
# 07/05/2026 19:17:20 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/tokenizer/chat_template.jinja "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 19:17:20 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/tokenizer/chat_template.jinja "HTTP/1.1 404 Not Found"
# 07/05/2026 19:17:20 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/text_encoder/config.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 19:17:21 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/text_encoder/config.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 19:17:21 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/text_encoder%2Fconfig.json "HTTP/1.1 200 OK"
# 07/05/2026 19:17:21 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/text_encoder%2Fconfig.json "HTTP/1.1 200 OK"
# config.json: 100% 617/617 [00:00<00:00, 3.31MB/s]
# 07/05/2026 19:17:21 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/text_encoder/adapter_config.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 19:17:21 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/text_encoder/adapter_config.json "HTTP/1.1 404 Not Found"
# 07/05/2026 19:17:21 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/text_encoder/config.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 19:17:22 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/text_encoder/config.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 19:17:22 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/text_encoder%2Fconfig.json "HTTP/1.1 200 OK"
# 07/05/2026 19:17:22 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/text_encoder/model.safetensors "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 19:17:22 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/text_encoder/model.safetensors "HTTP/1.1 302 Found"
# text_encoder/model.safetensors: 100% 492M/492M [00:05<00:00, 86.8MB/s]
# Loading weights: 100% 196/196 [00:00<00:00, 8710.08it/s]
# 07/05/2026 19:17:28 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/vae/config.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 19:17:28 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/vae/config.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 19:17:29 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae%2Fconfig.json "HTTP/1.1 200 OK"
# 07/05/2026 19:17:29 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae%2Fconfig.json "HTTP/1.1 200 OK"
# config.json: 100% 547/547 [00:00<00:00, 3.22MB/s]
# 07/05/2026 19:17:29 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae/diffusion_pytorch_model.safetensors.index.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 19:17:29 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae/diffusion_pytorch_model.safetensors.index.json "HTTP/1.1 404 Not Found"
# 07/05/2026 19:17:29 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae/diffusion_pytorch_model.safetensors "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 19:17:29 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae/diffusion_pytorch_model.safetensors "HTTP/1.1 302 Found"
# vae/diffusion_pytorch_model.safetensors: 100% 335M/335M [00:02<00:00, 116MB/s]
# {'scaling_factor', 'latents_mean', 'use_quant_conv', 'force_upcast', 'shift_factor', 'use_post_quant_conv', 'latents_std', 'mid_block_add_attention'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at runwayml/stable-diffusion-v1-5.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# 07/05/2026 19:17:33 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/unet/config.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 19:17:33 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/unet/config.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 19:17:33 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/unet%2Fconfig.json "HTTP/1.1 200 OK"
# 07/05/2026 19:17:33 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/unet%2Fconfig.json "HTTP/1.1 200 OK"
# config.json: 100% 743/743 [00:00<00:00, 2.40MB/s]
# 07/05/2026 19:17:33 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/unet/diffusion_pytorch_model.safetensors.index.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 19:17:33 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/unet/diffusion_pytorch_model.safetensors.index.json "HTTP/1.1 404 Not Found"
# 07/05/2026 19:17:34 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/unet/diffusion_pytorch_model.safetensors "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 19:17:34 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/unet/diffusion_pytorch_model.safetensors "HTTP/1.1 302 Found"
# unet/diffusion_pytorch_model.safetensors: 100% 3.44G/3.44G [01:05<00:00, 52.4MB/s]
# {'addition_embed_type_num_heads', 'time_cond_proj_dim', 'resnet_time_scale_shift', 'reverse_transformer_layers_per_block', 'cross_attention_norm', 'attention_type', 'class_embeddings_concat', 'use_linear_projection', 'addition_embed_type', 'time_embedding_act_fn', 'projection_class_embeddings_input_dim', 'num_class_embeds', 'dropout', 'conv_in_kernel', 'time_embedding_type', 'transformer_layers_per_block', 'encoder_hid_dim', 'num_attention_heads', 'timestep_post_act', 'resnet_out_scale_factor', 'addition_time_embed_dim', 'time_embedding_dim', 'mid_block_type', 'resnet_skip_time_act', 'encoder_hid_dim_type', 'only_cross_attention', 'dual_cross_attention', 'conv_out_kernel', 'mid_block_only_cross_attention', 'upcast_attention', 'class_embed_type'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing UNet2DConditionModel.
#
# All the weights of UNet2DConditionModel were initialized from the model checkpoint at runwayml/stable-diffusion-v1-5.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use UNet2DConditionModel for predictions without further training.
# There are modules in UNet2DConditionModel that should be kept in float32: []. Casting directly with `to()` can lead to inconsistent results; set `torch_dtype` in `from_pretrained()` instead to keep these modules in float32.
# There are modules in AutoencoderKL that should be kept in float32: []. Casting directly with `to()` can lead to inconsistent results; set `torch_dtype` in `from_pretrained()` instead to keep these modules in float32.
# Resolving data files: 100% 103/103 [00:00<00:00, 141922.90it/s]
# Downloading data: 100% 100/100 [00:00<00:00, 30486.29files/s]
# Generating train split: 100 examples [00:00, 3619.80 examples/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# 07/05/2026 19:18:59 - INFO - __main__ - [RANK 0] ***** Running training *****
# 07/05/2026 19:18:59 - INFO - __main__ - [RANK 0]   Num examples = 100
# 07/05/2026 19:18:59 - INFO - __main__ - [RANK 0]   Num Epochs = 44
# 07/05/2026 19:18:59 - INFO - __main__ - [RANK 0]   Instantaneous batch size per device = 1
# 07/05/2026 19:18:59 - INFO - __main__ - [RANK 0]   Total train batch size (w. parallel, distributed & accumulation) = 4
# 07/05/2026 19:18:59 - INFO - __main__ - [RANK 0]   Gradient Accumulation steps = 4
# 07/05/2026 19:18:59 - INFO - __main__ - [RANK 0]   Total optimization steps = 1100
# Steps:   0% 0/1100 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:432: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# Steps:  45% 500/1100 [13:08<16:03,  1.61s/it, lr=5.73e-5, step_loss=0.00687]07/05/2026 19:32:08 - INFO - accelerate.accelerator - [RANK 0] Saving current state to /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank8/checkpoint-500
# Model weights saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank8/checkpoint-500/pytorch_lora_weights.safetensors
# 07/05/2026 19:32:08 - INFO - accelerate.checkpointing - [RANK 0] Optimizer state saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank8/checkpoint-500/optimizer.bin
# 07/05/2026 19:32:08 - INFO - accelerate.checkpointing - [RANK 0] Scheduler state saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank8/checkpoint-500/scheduler.bin
# 07/05/2026 19:32:08 - INFO - accelerate.checkpointing - [RANK 0] Sampler state for dataloader 0 saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank8/checkpoint-500/sampler.bin
# 07/05/2026 19:32:08 - INFO - accelerate.checkpointing - [RANK 0] Gradient scaler state saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank8/checkpoint-500/scaler.pt
# 07/05/2026 19:32:08 - INFO - accelerate.checkpointing - [RANK 0] Random states saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank8/checkpoint-500/random_states_0.pkl
# 07/05/2026 19:32:08 - INFO - __main__ - [RANK 0] Saved state to /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank8/checkpoint-500
# Steps:  91% 1000/1100 [26:19<02:37,  1.58s/it, lr=2.07e-6, step_loss=0.0495]07/05/2026 19:45:19 - INFO - accelerate.accelerator - [RANK 0] Saving current state to /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank8/checkpoint-1000
# Model weights saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank8/checkpoint-1000/pytorch_lora_weights.safetensors
# 07/05/2026 19:45:20 - INFO - accelerate.checkpointing - [RANK 0] Optimizer state saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank8/checkpoint-1000/optimizer.bin
# 07/05/2026 19:45:20 - INFO - accelerate.checkpointing - [RANK 0] Scheduler state saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank8/checkpoint-1000/scheduler.bin
# 07/05/2026 19:45:20 - INFO - accelerate.checkpointing - [RANK 0] Sampler state for dataloader 0 saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank8/checkpoint-1000/sampler.bin
# 07/05/2026 19:45:20 - INFO - accelerate.checkpointing - [RANK 0] Gradient scaler state saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank8/checkpoint-1000/scaler.pt
# 07/05/2026 19:45:20 - INFO - accelerate.checkpointing - [RANK 0] Random states saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank8/checkpoint-1000/random_states_0.pkl
# 07/05/2026 19:45:20 - INFO - __main__ - [RANK 0] Saved state to /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank8/checkpoint-1000
# Steps: 100% 1100/1100 [28:58<00:00,  1.59s/it, lr=0, step_loss=0.223]        There are modules in UNet2DConditionModel that should be kept in float32: []. Casting directly with `to()` can lead to inconsistent results; set `torch_dtype` in `from_pretrained()` instead to keep these modules in float32.
# Model weights saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank8/pytorch_lora_weights.safetensors
# Steps: 100% 1100/1100 [28:59<00:00,  1.58s/it, lr=0, step_loss=0.223]

# %%
# Célula 4B: CONFIGURAÇÃO B (Rank 16) - Ponto de Equilíbrio (Trade-off)
# !accelerate launch diffusers/examples/text_to_image/train_text_to_image_lora.py \
  --pretrained_model_name_or_path="runwayml/stable-diffusion-v1-5" \
  --dataset_name="/content/atelie-generativo-estilo-pixel-art/dataset" \
  --dataloader_num_workers=8 \
  --resolution=512 \
  --center_crop \
  --random_flip \
  --train_batch_size=1 \
  --gradient_accumulation_steps=4 \
  --max_train_steps=1200 \
  --learning_rate=1e-04 \
  --max_grad_norm=1 \
  --lr_scheduler="cosine" \
  --lr_warmup_steps=0 \
  --output_dir="/content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank16" \
  --checkpointing_steps=500 \
  --seed=42 \
  --rank=16 \
  --mixed_precision="fp16" \
  --enable_xformers_memory_efficient_attention
# Out:
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Unable to import `torchao` Tensor objects. This may affect loading checkpoints serialized with `torchao`
# Flax classes are deprecated and will be removed in Diffusers v0.40.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v0.40.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# 07/05/2026 20:31:57 - INFO - __main__ - [RANK 0] Distributed environment: DistributedType.NO
# Num processes: 1
# Process index: 0
# Local process index: 0
# Device: cuda
#
# Mixed precision type: fp16
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py:205: UserWarning: The `local_dir_use_symlinks` argument is deprecated and ignored in `hf_hub_download`. Downloading to a local directory does not use symlinks anymore.
#   warnings.warn(
# 07/05/2026 20:31:58 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/agent-harnesses "HTTP/1.1 200 OK"
# 07/05/2026 20:31:58 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/scheduler/scheduler_config.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 20:31:58 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/scheduler/scheduler_config.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 20:31:58 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/scheduler%2Fscheduler_config.json "HTTP/1.1 200 OK"
# 07/05/2026 20:31:58 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/scheduler%2Fscheduler_config.json "HTTP/1.1 200 OK"
# scheduler_config.json: 100% 308/308 [00:00<00:00, 1.48MB/s]
# {'prediction_type', 'variance_type', 'rescale_betas_zero_snr', 'thresholding', 'clip_sample_range', 'dynamic_thresholding_ratio', 'sample_max_value', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# 07/05/2026 20:31:58 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/tokenizer/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 20:31:58 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/tokenizer/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 07/05/2026 20:31:58 - WARNING - huggingface_hub.utils._http - Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 07/05/2026 20:31:58 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/tokenizer%2Ftokenizer_config.json "HTTP/1.1 200 OK"
# 07/05/2026 20:31:58 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/tokenizer%2Ftokenizer_config.json "HTTP/1.1 200 OK"
# tokenizer_config.json: 100% 806/806 [00:00<00:00, 5.46MB/s]
# 07/05/2026 20:31:58 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/models/runwayml/stable-diffusion-v1-5/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 20:31:58 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/models/stable-diffusion-v1-5/stable-diffusion-v1-5/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# 07/05/2026 20:31:58 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/models/runwayml/stable-diffusion-v1-5/tree/main?recursive=true&expand=false "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 20:31:58 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/models/stable-diffusion-v1-5/stable-diffusion-v1-5/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# 07/05/2026 20:31:58 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/tokenizer/vocab.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 20:31:59 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/tokenizer/vocab.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 20:31:59 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/tokenizer%2Fvocab.json "HTTP/1.1 200 OK"
# 07/05/2026 20:31:59 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/tokenizer%2Fvocab.json "HTTP/1.1 200 OK"
# vocab.json: 100% 1.06M/1.06M [00:00<00:00, 58.9MB/s]
# 07/05/2026 20:31:59 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/tokenizer/merges.txt "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 20:31:59 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/tokenizer/merges.txt "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 20:31:59 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/tokenizer%2Fmerges.txt "HTTP/1.1 200 OK"
# 07/05/2026 20:31:59 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/tokenizer%2Fmerges.txt "HTTP/1.1 200 OK"
# merges.txt: 100% 525k/525k [00:00<00:00, 113MB/s]
# 07/05/2026 20:31:59 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/tokenizer/tokenizer.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 20:31:59 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/tokenizer/tokenizer.json "HTTP/1.1 404 Not Found"
# 07/05/2026 20:31:59 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/tokenizer/added_tokens.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 20:31:59 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/tokenizer/added_tokens.json "HTTP/1.1 404 Not Found"
# 07/05/2026 20:31:59 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/tokenizer/special_tokens_map.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 20:31:59 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/tokenizer/special_tokens_map.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 20:31:59 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/tokenizer%2Fspecial_tokens_map.json "HTTP/1.1 200 OK"
# 07/05/2026 20:31:59 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/tokenizer%2Fspecial_tokens_map.json "HTTP/1.1 200 OK"
# special_tokens_map.json: 100% 472/472 [00:00<00:00, 3.31MB/s]
# 07/05/2026 20:31:59 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/tokenizer/chat_template.jinja "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 20:31:59 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/tokenizer/chat_template.jinja "HTTP/1.1 404 Not Found"
# 07/05/2026 20:32:00 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/text_encoder/config.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 20:32:00 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/text_encoder/config.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 20:32:00 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/text_encoder%2Fconfig.json "HTTP/1.1 200 OK"
# 07/05/2026 20:32:00 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/text_encoder%2Fconfig.json "HTTP/1.1 200 OK"
# config.json: 100% 617/617 [00:00<00:00, 4.79MB/s]
# 07/05/2026 20:32:00 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/text_encoder/adapter_config.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 20:32:00 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/text_encoder/adapter_config.json "HTTP/1.1 404 Not Found"
# 07/05/2026 20:32:00 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/text_encoder/config.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 20:32:00 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/text_encoder/config.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 20:32:00 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/text_encoder%2Fconfig.json "HTTP/1.1 200 OK"
# 07/05/2026 20:32:00 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/text_encoder/model.safetensors "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 20:32:00 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/text_encoder/model.safetensors "HTTP/1.1 302 Found"
# text_encoder/model.safetensors: 100% 492M/492M [00:03<00:00, 128MB/s]
# Loading weights: 100% 196/196 [00:00<00:00, 14697.12it/s]
# 07/05/2026 20:32:04 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/vae/config.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 20:32:05 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/vae/config.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 20:32:05 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae%2Fconfig.json "HTTP/1.1 200 OK"
# 07/05/2026 20:32:05 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae%2Fconfig.json "HTTP/1.1 200 OK"
# config.json: 100% 547/547 [00:00<00:00, 2.48MB/s]
# 07/05/2026 20:32:05 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae/diffusion_pytorch_model.safetensors.index.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 20:32:05 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae/diffusion_pytorch_model.safetensors.index.json "HTTP/1.1 404 Not Found"
# 07/05/2026 20:32:05 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae/diffusion_pytorch_model.safetensors "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 20:32:05 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae/diffusion_pytorch_model.safetensors "HTTP/1.1 302 Found"
# vae/diffusion_pytorch_model.safetensors: 100% 335M/335M [00:04<00:00, 72.5MB/s]
# {'use_quant_conv', 'use_post_quant_conv', 'shift_factor', 'latents_std', 'scaling_factor', 'mid_block_add_attention', 'force_upcast', 'latents_mean'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at runwayml/stable-diffusion-v1-5.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# 07/05/2026 20:32:10 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/unet/config.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 20:32:10 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/unet/config.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 20:32:10 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/unet%2Fconfig.json "HTTP/1.1 200 OK"
# 07/05/2026 20:32:10 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/unet%2Fconfig.json "HTTP/1.1 200 OK"
# config.json: 100% 743/743 [00:00<00:00, 4.38MB/s]
# 07/05/2026 20:32:10 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/unet/diffusion_pytorch_model.safetensors.index.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 20:32:10 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/unet/diffusion_pytorch_model.safetensors.index.json "HTTP/1.1 404 Not Found"
# 07/05/2026 20:32:10 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/unet/diffusion_pytorch_model.safetensors "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 20:32:10 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/unet/diffusion_pytorch_model.safetensors "HTTP/1.1 302 Found"
# unet/diffusion_pytorch_model.safetensors: 100% 3.44G/3.44G [00:39<00:00, 86.2MB/s]
# {'conv_in_kernel', 'addition_embed_type', 'attention_type', 'num_attention_heads', 'mid_block_type', 'addition_time_embed_dim', 'dropout', 'num_class_embeds', 'class_embeddings_concat', 'upcast_attention', 'only_cross_attention', 'timestep_post_act', 'encoder_hid_dim_type', 'projection_class_embeddings_input_dim', 'mid_block_only_cross_attention', 'reverse_transformer_layers_per_block', 'encoder_hid_dim', 'cross_attention_norm', 'resnet_skip_time_act', 'class_embed_type', 'time_embedding_act_fn', 'time_embedding_dim', 'resnet_time_scale_shift', 'addition_embed_type_num_heads', 'transformer_layers_per_block', 'use_linear_projection', 'time_embedding_type', 'resnet_out_scale_factor', 'dual_cross_attention', 'conv_out_kernel', 'time_cond_proj_dim'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing UNet2DConditionModel.
#
# All the weights of UNet2DConditionModel were initialized from the model checkpoint at runwayml/stable-diffusion-v1-5.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use UNet2DConditionModel for predictions without further training.
# There are modules in UNet2DConditionModel that should be kept in float32: []. Casting directly with `to()` can lead to inconsistent results; set `torch_dtype` in `from_pretrained()` instead to keep these modules in float32.
# There are modules in AutoencoderKL that should be kept in float32: []. Casting directly with `to()` can lead to inconsistent results; set `torch_dtype` in `from_pretrained()` instead to keep these modules in float32.
# Resolving data files: 100% 103/103 [00:00<00:00, 160659.47it/s]
# Downloading data: 100% 100/100 [00:00<00:00, 187496.83files/s]
# Generating train split: 100 examples [00:00, 1944.70 examples/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# 07/05/2026 20:33:09 - INFO - __main__ - [RANK 0] ***** Running training *****
# 07/05/2026 20:33:09 - INFO - __main__ - [RANK 0]   Num examples = 100
# 07/05/2026 20:33:09 - INFO - __main__ - [RANK 0]   Num Epochs = 48
# 07/05/2026 20:33:09 - INFO - __main__ - [RANK 0]   Instantaneous batch size per device = 1
# 07/05/2026 20:33:09 - INFO - __main__ - [RANK 0]   Total train batch size (w. parallel, distributed & accumulation) = 4
# 07/05/2026 20:33:09 - INFO - __main__ - [RANK 0]   Gradient Accumulation steps = 4
# 07/05/2026 20:33:09 - INFO - __main__ - [RANK 0]   Total optimization steps = 1200
# Steps:   0% 0/1200 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:432: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# Steps:  42% 500/1200 [12:39<18:10,  1.56s/it, lr=6.31e-5, step_loss=0.00629]07/05/2026 20:45:48 - INFO - accelerate.accelerator - [RANK 0] Saving current state to /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank16/checkpoint-500
# Model weights saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank16/checkpoint-500/pytorch_lora_weights.safetensors
# 07/05/2026 20:45:48 - INFO - accelerate.checkpointing - [RANK 0] Optimizer state saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank16/checkpoint-500/optimizer.bin
# 07/05/2026 20:45:48 - INFO - accelerate.checkpointing - [RANK 0] Scheduler state saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank16/checkpoint-500/scheduler.bin
# 07/05/2026 20:45:48 - INFO - accelerate.checkpointing - [RANK 0] Sampler state for dataloader 0 saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank16/checkpoint-500/sampler.bin
# 07/05/2026 20:45:48 - INFO - accelerate.checkpointing - [RANK 0] Gradient scaler state saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank16/checkpoint-500/scaler.pt
# 07/05/2026 20:45:48 - INFO - accelerate.checkpointing - [RANK 0] Random states saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank16/checkpoint-500/random_states_0.pkl
# 07/05/2026 20:45:48 - INFO - __main__ - [RANK 0] Saved state to /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank16/checkpoint-500
# Steps:  83% 1000/1200 [25:26<05:06,  1.53s/it, lr=6.76e-6, step_loss=0.0835]07/05/2026 20:58:36 - INFO - accelerate.accelerator - [RANK 0] Saving current state to /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank16/checkpoint-1000
# Model weights saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank16/checkpoint-1000/pytorch_lora_weights.safetensors
# 07/05/2026 20:58:36 - INFO - accelerate.checkpointing - [RANK 0] Optimizer state saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank16/checkpoint-1000/optimizer.bin
# 07/05/2026 20:58:36 - INFO - accelerate.checkpointing - [RANK 0] Scheduler state saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank16/checkpoint-1000/scheduler.bin
# 07/05/2026 20:58:36 - INFO - accelerate.checkpointing - [RANK 0] Sampler state for dataloader 0 saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank16/checkpoint-1000/sampler.bin
# 07/05/2026 20:58:36 - INFO - accelerate.checkpointing - [RANK 0] Gradient scaler state saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank16/checkpoint-1000/scaler.pt
# 07/05/2026 20:58:36 - INFO - accelerate.checkpointing - [RANK 0] Random states saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank16/checkpoint-1000/random_states_0.pkl
# 07/05/2026 20:58:36 - INFO - __main__ - [RANK 0] Saved state to /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank16/checkpoint-1000
# Steps: 100% 1200/1200 [30:33<00:00,  1.54s/it, lr=0, step_loss=0.0115]        There are modules in UNet2DConditionModel that should be kept in float32: []. Casting directly with `to()` can lead to inconsistent results; set `torch_dtype` in `from_pretrained()` instead to keep these modules in float32.
# Model weights saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank16/pytorch_lora_weights.safetensors
# Steps: 100% 1200/1200 [30:33<00:00,  1.53s/it, lr=0, step_loss=0.0115]

# %%
# Célula 4C: CONFIGURAÇÃO C (Rank 32) - Alta Fidelidade de Detalhes
# !accelerate launch diffusers/examples/text_to_image/train_text_to_image_lora.py \
  --pretrained_model_name_or_path="runwayml/stable-diffusion-v1-5" \
  --dataset_name="/content/atelie-generativo-estilo-pixel-art/dataset" \
  --dataloader_num_workers=8 \
  --resolution=512 \
  --center_crop \
  --random_flip \
  --train_batch_size=1 \
  --gradient_accumulation_steps=4 \
  --max_train_steps=1500 \
  --learning_rate=1e-04 \
  --max_grad_norm=1 \
  --lr_scheduler="cosine" \
  --lr_warmup_steps=0 \
  --output_dir="/content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32" \
  --checkpointing_steps=500 \
  --seed=42 \
  --rank=32 \
  --mixed_precision="fp16" \
  --enable_xformers_memory_efficient_attention
# Out:
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Unable to import `torchao` Tensor objects. This may affect loading checkpoints serialized with `torchao`
# Flax classes are deprecated and will be removed in Diffusers v0.40.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v0.40.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# 07/05/2026 21:04:58 - INFO - __main__ - [RANK 0] Distributed environment: DistributedType.NO
# Num processes: 1
# Process index: 0
# Local process index: 0
# Device: cuda
#
# Mixed precision type: fp16
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py:205: UserWarning: The `local_dir_use_symlinks` argument is deprecated and ignored in `hf_hub_download`. Downloading to a local directory does not use symlinks anymore.
#   warnings.warn(
# 07/05/2026 21:04:58 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/scheduler/scheduler_config.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 21:04:58 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/scheduler/scheduler_config.json "HTTP/1.1 307 Temporary Redirect"
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 07/05/2026 21:04:58 - WARNING - huggingface_hub.utils._http - Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 07/05/2026 21:04:58 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/scheduler%2Fscheduler_config.json "HTTP/1.1 200 OK"
# {'rescale_betas_zero_snr', 'variance_type', 'sample_max_value', 'thresholding', 'dynamic_thresholding_ratio', 'clip_sample_range', 'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# 07/05/2026 21:04:58 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/tokenizer/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 21:04:58 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/tokenizer/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 21:04:58 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/tokenizer%2Ftokenizer_config.json "HTTP/1.1 200 OK"
# 07/05/2026 21:04:58 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/models/runwayml/stable-diffusion-v1-5/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 21:04:58 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/models/stable-diffusion-v1-5/stable-diffusion-v1-5/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# 07/05/2026 21:04:58 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/models/runwayml/stable-diffusion-v1-5/tree/main?recursive=true&expand=false "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 21:04:58 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/models/stable-diffusion-v1-5/stable-diffusion-v1-5/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# 07/05/2026 21:04:59 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/text_encoder/config.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 21:04:59 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/text_encoder/config.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 21:04:59 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/text_encoder%2Fconfig.json "HTTP/1.1 200 OK"
# 07/05/2026 21:04:59 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/text_encoder/config.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 21:04:59 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/text_encoder/config.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 21:04:59 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/text_encoder%2Fconfig.json "HTTP/1.1 200 OK"
# 07/05/2026 21:04:59 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/text_encoder/model.safetensors "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 21:04:59 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/text_encoder/model.safetensors "HTTP/1.1 302 Found"
# Loading weights: 100% 196/196 [00:00<00:00, 3528.97it/s]
# 07/05/2026 21:04:59 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/vae/config.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 21:04:59 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/vae/config.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 21:04:59 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae%2Fconfig.json "HTTP/1.1 200 OK"
# 07/05/2026 21:04:59 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae/diffusion_pytorch_model.safetensors.index.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 21:05:00 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae/diffusion_pytorch_model.safetensors.index.json "HTTP/1.1 404 Not Found"
# {'latents_mean', 'scaling_factor', 'force_upcast', 'mid_block_add_attention', 'use_post_quant_conv', 'latents_std', 'shift_factor', 'use_quant_conv'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at runwayml/stable-diffusion-v1-5.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# 07/05/2026 21:05:00 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/unet/config.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 21:05:00 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/unet/config.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 21:05:00 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/unet%2Fconfig.json "HTTP/1.1 200 OK"
# 07/05/2026 21:05:00 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/unet/diffusion_pytorch_model.safetensors.index.json "HTTP/1.1 307 Temporary Redirect"
# 07/05/2026 21:05:00 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/unet/diffusion_pytorch_model.safetensors.index.json "HTTP/1.1 404 Not Found"
# {'upcast_attention', 'addition_time_embed_dim', 'class_embed_type', 'reverse_transformer_layers_per_block', 'class_embeddings_concat', 'conv_in_kernel', 'time_embedding_type', 'time_embedding_dim', 'addition_embed_type_num_heads', 'dropout', 'encoder_hid_dim_type', 'num_attention_heads', 'conv_out_kernel', 'resnet_out_scale_factor', 'cross_attention_norm', 'transformer_layers_per_block', 'only_cross_attention', 'resnet_time_scale_shift', 'dual_cross_attention', 'num_class_embeds', 'attention_type', 'addition_embed_type', 'mid_block_only_cross_attention', 'mid_block_type', 'timestep_post_act', 'encoder_hid_dim', 'use_linear_projection', 'time_cond_proj_dim', 'resnet_skip_time_act', 'time_embedding_act_fn', 'projection_class_embeddings_input_dim'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing UNet2DConditionModel.
#
# All the weights of UNet2DConditionModel were initialized from the model checkpoint at runwayml/stable-diffusion-v1-5.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use UNet2DConditionModel for predictions without further training.
# There are modules in UNet2DConditionModel that should be kept in float32: []. Casting directly with `to()` can lead to inconsistent results; set `torch_dtype` in `from_pretrained()` instead to keep these modules in float32.
# There are modules in AutoencoderKL that should be kept in float32: []. Casting directly with `to()` can lead to inconsistent results; set `torch_dtype` in `from_pretrained()` instead to keep these modules in float32.
# Resolving data files: 100% 103/103 [00:00<00:00, 26141.43it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# 07/05/2026 21:05:21 - INFO - __main__ - [RANK 0] ***** Running training *****
# 07/05/2026 21:05:21 - INFO - __main__ - [RANK 0]   Num examples = 100
# 07/05/2026 21:05:21 - INFO - __main__ - [RANK 0]   Num Epochs = 60
# 07/05/2026 21:05:21 - INFO - __main__ - [RANK 0]   Instantaneous batch size per device = 1
# 07/05/2026 21:05:21 - INFO - __main__ - [RANK 0]   Total train batch size (w. parallel, distributed & accumulation) = 4
# 07/05/2026 21:05:21 - INFO - __main__ - [RANK 0]   Gradient Accumulation steps = 4
# 07/05/2026 21:05:21 - INFO - __main__ - [RANK 0]   Total optimization steps = 1500
# Steps:   0% 0/1500 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:432: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# Steps:  33% 500/1500 [12:53<25:21,  1.52s/it, lr=7.51e-5, step_loss=0.00612]07/05/2026 21:18:14 - INFO - accelerate.accelerator - [RANK 0] Saving current state to /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/checkpoint-500
# Model weights saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/checkpoint-500/pytorch_lora_weights.safetensors
# 07/05/2026 21:18:14 - INFO - accelerate.checkpointing - [RANK 0] Optimizer state saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/checkpoint-500/optimizer.bin
# 07/05/2026 21:18:14 - INFO - accelerate.checkpointing - [RANK 0] Scheduler state saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/checkpoint-500/scheduler.bin
# 07/05/2026 21:18:14 - INFO - accelerate.checkpointing - [RANK 0] Sampler state for dataloader 0 saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/checkpoint-500/sampler.bin
# 07/05/2026 21:18:14 - INFO - accelerate.checkpointing - [RANK 0] Gradient scaler state saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/checkpoint-500/scaler.pt
# 07/05/2026 21:18:14 - INFO - accelerate.checkpointing - [RANK 0] Random states saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/checkpoint-500/random_states_0.pkl
# 07/05/2026 21:18:14 - INFO - __main__ - [RANK 0] Saved state to /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/checkpoint-500
# Steps:  67% 1000/1500 [25:43<12:45,  1.53s/it, lr=2.51e-5, step_loss=0.0798]07/05/2026 21:31:04 - INFO - accelerate.accelerator - [RANK 0] Saving current state to /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/checkpoint-1000
# Model weights saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/checkpoint-1000/pytorch_lora_weights.safetensors
# 07/05/2026 21:31:05 - INFO - accelerate.checkpointing - [RANK 0] Optimizer state saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/checkpoint-1000/optimizer.bin
# 07/05/2026 21:31:05 - INFO - accelerate.checkpointing - [RANK 0] Scheduler state saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/checkpoint-1000/scheduler.bin
# 07/05/2026 21:31:05 - INFO - accelerate.checkpointing - [RANK 0] Sampler state for dataloader 0 saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/checkpoint-1000/sampler.bin
# 07/05/2026 21:31:05 - INFO - accelerate.checkpointing - [RANK 0] Gradient scaler state saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/checkpoint-1000/scaler.pt
# 07/05/2026 21:31:05 - INFO - accelerate.checkpointing - [RANK 0] Random states saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/checkpoint-1000/random_states_0.pkl
# 07/05/2026 21:31:05 - INFO - __main__ - [RANK 0] Saved state to /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/checkpoint-1000
# Steps: 100% 1500/1500 [38:33<00:00,  1.58s/it, lr=1.1e-10, step_loss=0.00919]07/05/2026 21:43:54 - INFO - accelerate.accelerator - [RANK 0] Saving current state to /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/checkpoint-1500
# Model weights saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/checkpoint-1500/pytorch_lora_weights.safetensors
# 07/05/2026 21:43:55 - INFO - accelerate.checkpointing - [RANK 0] Optimizer state saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/checkpoint-1500/optimizer.bin
# 07/05/2026 21:43:55 - INFO - accelerate.checkpointing - [RANK 0] Scheduler state saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/checkpoint-1500/scheduler.bin
# 07/05/2026 21:43:55 - INFO - accelerate.checkpointing - [RANK 0] Sampler state for dataloader 0 saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/checkpoint-1500/sampler.bin
# 07/05/2026 21:43:55 - INFO - accelerate.checkpointing - [RANK 0] Gradient scaler state saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/checkpoint-1500/scaler.pt
# 07/05/2026 21:43:55 - INFO - accelerate.checkpointing - [RANK 0] Random states saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/checkpoint-1500/random_states_0.pkl
# 07/05/2026 21:43:55 - INFO - __main__ - [RANK 0] Saved state to /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/checkpoint-1500
# Steps: 100% 1500/1500 [38:33<00:00,  1.58s/it, lr=0, step_loss=0.102]        There are modules in UNet2DConditionModel that should be kept in float32: []. Casting directly with `to()` can lead to inconsistent results; set `torch_dtype` in `from_pretrained()` instead to keep these modules in float32.
# Model weights saved in /content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32/pytorch_lora_weights.safetensors
# Steps: 100% 1500/1500 [38:34<00:00,  1.54s/it, lr=0, step_loss=0.102]

# %% [markdown]
# **5 - Inferência e Validação Visual**
#
# > Após o treino, os arquivos *.safetensors* dos seus LoRAs estarão a salvo no seu Google Drive. Use esta célula para carregar o modelo treinado e testar se ele aprendeu o estilo!

# %%
# Célula 5: Teste de Geração e Validação Visual
import torch
from diffusers import StableDiffusionPipeline
from IPython.display import display # Importação vital para renderizar imagens no Colab

# 1. Carrega o modelo fundacional em precisão de 16-bits para caber na GPU
pipe = StableDiffusionPipeline.from_pretrained("runwayml/stable-diffusion-v1-5", torch_dtype=torch.float16)
pipe.to("cuda")

# 2. Injeta os pesos do seu LoRA treinado (Vamos testar o Rank 32)
caminho_do_lora = "/content/drive/MyDrive/Atelie_Generativo_LoRA/PixelArt_Rank32"
pipe.load_lora_weights(caminho_do_lora)

# 3. Geração no Espaço Latente
prompt = "estilo_pixel_art, cena em pixel art com uma cabana rural e árvores de sakura ao redor."

print("🎨 Sintetizando imagem no espaço latente...")
imagem = pipe(prompt, num_inference_steps=200, guidance_scale=9.0).images[0]

# 4. Exibe o resultado visualmente dentro do Colab!
print("\n✨ Resultado da Inferência:")
display(imagem)
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/396 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/196 [00:00<?, ?it/s]
# No LoRA keys associated to CLIPTextModel found with the prefix='text_encoder'. This is safe to ignore if LoRA state dict didn't originally have any CLIPTextModel related params. You can also try specifying `prefix=None` to resolve the warning. Otherwise, open an issue if you think it's unexpected: https://github.com/huggingface/diffusers/issues/new
# 🎨 Sintetizando imagem no espaço latente...
#   0%|          | 0/200 [00:00<?, ?it/s]
# ✨ Resultado da Inferência:
# <PIL.Image.Image image mode=RGB size=512x512>
